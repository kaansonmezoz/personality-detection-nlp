# %% [markdown]
# <span style="font-size:1.1em;">Colab'a Google drive'ı entegre ediyoruz. Kullanılacak olan veriseti Google Drive'da bulunmaktadır</span>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd

# %% [markdown]
# <span style="font-size:1.1em;">Google Drive'ımızın root pathi</span> ```gdrive/My Drive``` <span style="font-size:1.1em;">oluyor. Proje için gerekli verisetini **mbti** adında bir klasör oluşturup içerisine yüklüyoruz. İlgili verisetinin pathi</span> ```gdrive/My Drive/mbti/all_users.csv``` <span style="font-size:1.1em;">oluyor.</span>

# %%
df = pd.read_csv("gdrive/My Drive/mbti/eliminated_all_users_v2.csv", sep = ';', header = 0)

# %%
df
# Out:
#             user                                              entry  type  \
# 0       19991991  ekşi itiraf sonunda döndüm dolaştım geldim ken...  ENTJ
# 1       19991991  selda bağcan bu sesi canlı dinleyebilmek benim...  ENTJ
# 2       19991991  eski sevgilisinin mutlu olmasını isteyen insan...  ENTJ
# 3       19991991  veda ederken 2019'a bir not bırakmak farklı ac...  ENTJ
# 4       19991991  ingiliz aksanı bu aralar özellikle bayıldığım ...  ENTJ
# ...          ...                                                ...   ...
# 524835  zaimoglu          zlatan ibrahimoviç türkiye de katil olur   ESFJ
# 524836  zaimoglu  tarihteki en büyük yalancılar şike operasyonu ...  ESFJ
# 524837  zaimoglu            akp-chp koalisyonu hayali koalisyondur   ESFJ
# 524838  zaimoglu  trabzonlu insana hamsi diyen fenerbahçe taraft...  ESFJ
# 524839  zaimoglu  caner taslaman zonguldak taki paneline katılma...  ESFJ
#
#         typeClass I/E S/N T/F J/P
# 0        analysts   E   N   T   J
# 1        analysts   E   N   T   J
# 2        analysts   E   N   T   J
# 3        analysts   E   N   T   J
# 4        analysts   E   N   T   J
# ...           ...  ..  ..  ..  ..
# 524835  sentinels   E   S   F   J
# 524836  sentinels   E   S   F   J
# 524837  sentinels   E   S   F   J
# 524838  sentinels   E   S   F   J
# 524839  sentinels   E   S   F   J
#
# [524840 rows x 8 columns]

# %% [markdown]
# # Pre-Processing
#
# <span style="font-size:1.1em;"> Entrylere ön işleme adımları uygulanır. Bu adımlar:</span>
#
#
# 1. <span style="font-size:1.1em;">Bütün harflerin küçük harf haline getirilmesi</span>
#
#
# 2. <span style="font-size:1.1em;">Entrylerden stop words'ler silinmelidir.</span>
#
#
# 3. <span style="font-size:1.1em;">Web sitelerinin temizlenmesi</span>
#
#
# 4. <span style="font-size:1.1em;">Noktalama işaretlerinin temizlenmesi</span>
#
#
# 5. <span style="font-size:1.1em;">Rakamların temizlenmesi</span>
#
#
# 6. <span style="font-size:1.1em;">Stemming kullanılması</span>
#
#
# <span style="font-size:1.1em;">
# Temizlenme işlemlerinde empty string yerine space (' ') ile replace edilerek yapılmalıdır. Arından da fazla boşluklar vs trim edilmelidir.
#
# ```[+-]?([0-9]*)([.][0-9])?``` regex olarak kullanılacak hem rakamların silinmesinde hem de ondaklı sayıların silinmesinde --> buna gerek kalmadı
#
# </span>

# %% [markdown]
# <span style="font-size:1.1em;"> Stop words, drive'da /mbti altındaki stop_words_tr.txt okunarak alınır</span>

# %%
file = open("gdrive/My Drive/mbti/stop_words_tr.txt")
stop_word_list = file.read().split('\n')
file.close()

# %%
stop_word_list
# Out:
# ['a',
#  'aa',
#  'aaa',
#  'aaah',
#  'aah',
#  'abe',
#  'abes',
#  'abo',
#  'abosa',
#  'abov',
#  'abow',
#  'abu',
#  'aç',
#  'acaba',
#  'acayip',
#  'accelerando',
#  'acele',
#  'aceleten',
#  'acep',
#  'açık',
#  'açıkça',
#  'açıkçası',
#  'açıktan',
#  'acilen',
#  'acımasız',
#  'acımasızcasına',
#  'âciz',
#  'âcizane',
#  'adamakıllı',
#  'adamcasına',
#  'adedî',
#  'adeta',
#  'âdeta',
#  'adilane',
#  'adına',
#  'afedersin',
#  'afedersinin',
#  'aferin',
#  'affettuoso',
#  'ağababa',
#  'ağabey',
#  'ağır',
#  'agitato',
#  'ağızdan',
#  'agucuk',
#  'ah',
#  'aha',
#  'ahacık',
#  'ahbap',
#  'aheste',
#  'ahir',
#  'ahiren',
#  'ahlaken',
#  'ailecek',
#  'ait',
#  'akabinde',
#  'akıbet',
#  'akilane',
#  'aklen',
#  'aklınca',
#  'akşamdan',
#  'akşamları',
#  'akşamleyin',
#  'akşamüstü',
#  'akşamüzeri',
#  'aksine',
#  'alabildiğine',
#  'alarga',
#  'alelacele',
#  'alelhesap',
#  'alelhusus',
#  'alelıtlak',
#  'alelumum',
#  'alelusul',
#  'âlem',
#  'alenen',
#  'alessabah',
#  'aleykümselâm',
#  'alicenap',
#  'alimallah',
#  'âlimane',
#  'allahtan',
#  'allegretto',
#  'allegro',
#  'alo',
#  'altı',
#  'altıncı',
#  'altışar',
#  'altmış',
#  'ama',
#  'amabile',
#  'aman',
#  'amanın',
#  'amca',
#  'amenna',
#  'âmin',
#  'amirane',
#  'amma',
#  'an',
#  'ana',
#  'anafordan',
#  'anal',
#  'anasıl',
#  'anbean',
#  'anca',
#  'ancak',
#  'andante',
#  'andantino',
#  'ani',
#  'aniden',
#  'anif',
#  'animato',
#  'anında',
#  'anlaşılan',
#  'ansızın',
#  'antrparantez',
#  'apaçık',
#  'apak',
#  'apansız',
#  'apansızın',
#  'apartopar',
#  'aport',
#  'appassionato',
#  'aptal',
#  'aptalcasına',
#  'aracılığıyla',
#  'arada',
#  'aralıkta',
#  'arasıra',
#  'ardarda',
#  'ardınca',
#  'ardından',
#  'arifane',
#  'ariyeten',
#  'arkadan',
#  'arkadaşça',
#  'arkaüstü',
#  'arş',
#  'artık',
#  'asabi',
#  'aşağı',
#  'asaleten',
#  'âşık',
#  'âşıkane',
#  'aşikâre',
#  'asıl',
#  'aşırı',
#  'aşkın',
#  'asla',
#  'aslen',
#  'aslında',
#  'atbaşı',
#  'atfen',
#  'atmış',
#  'atmışar',
#  'atmışıncı',
#  'avantadan',
#  'avara',
#  'ay',
#  'ayakta',
#  'ayaküstü',
#  'ayaküzeri',
#  'aybeay',
#  'ayı',
#  'ayık',
#  'aylarca',
#  'aylık',
#  'aynen',
#  'aynıyla',
#  'ayol',
#  'ayrı',
#  'ayrıca',
#  'ayrıyeten',
#  'az',
#  'azade',
#  'azıcık',
#  'azimkârane',
#  'b',
#  'ba',
#  'bacı',
#  'badehu',
#  'badema',
#  'bahar',
#  'bahusus',
#  'bakarak',
#  'bakımından',
#  'bakındı',
#  'balıklama',
#  'balıksırtı',
#  'bana',
#  'banko',
#  'bari',
#  'başbaşa',
#  'basbayağı',
#  'başıboş',
#  'baska',
#  'başka',
#  'başkası',
#  'başkasına',
#  'başkasında',
#  'başkasından',
#  'başkasını',
#  'başkasının',
#  'başlıbaşına',
#  'basmakalıp',
#  'başta',
#  'baştan',
#  'baştanbaşa',
#  'başüstüne',
#  'batsat',
#  'bayağı',
#  'bayan',
#  'baygın',
#  'bayramüstü',
#  'bayramüzeri',
#  'bazan',
#  'bazen',
#  'bazı',
#  'bazıları',
#  'bazısı',
#  'bazısına',
#  'bazısında',
#  'bazısından',
#  'bazısını',
#  'bazısının',
#  'be',
#  'bebek',
#  'bebekçe',
#  'bedaheten',
#  'bedava',
#  'bedavadan',
#  'bedavasına',
#  'bedavaya',
#  'bedenen',
#  'begayet',
#  'behemehâl',
#  'behey',
#  'beleşten',
#  'beli',
#  'belirgin',
#  'belki',
#  'bembeyaz',
#  'ben',
#  'bence',
#  'bencileyin',
#  'bende',
#  'benden',
#  'beni',
#  'benim',
#  'benimki',
#  'beraber',
#  'beraberce',
#  'berabere',
#  'beraberinde',
#  'bereket',
#  'berenarı',
#  'beri',
#  'beriki',
#  'berikinin',
#  'berikiyi',
#  'berisi',
#  'bermutat',
#  'bertafsil',
#  'bertaraf',
#  'beş',
#  'besbelli',
#  'beşer',
#  'beşinci',
#  'besmelesiz',
#  'beşyüz',
#  'beybaba',
#  'beyhude',
#  'beyninde',
#  'bezgin',
#  'bi',
#  'biçimli',
#  'bihaber',
#  'bihakkın',
#  'biilaç',
#  'bikes',
#  'bilahare',
#  'bilaistisna',
#  'bilakis',
#  'bilasebep',
#  'bilavasıta',
#  'bilcümle',
#  'bıldır',
#  'bile',
#  'bilerek',
#  'bilfarz',
#  'bilfiil',
#  'bilhassa',
#  'bililtizam',
#  'bilistifade',
#  'billahi',
#  'bilmukabele',
#  'bilmünasebe',
#  'bilvasıta',
#  'bin',
#  'binaen',
#  'binaenaleyh',
#  'biner',
#  'bininci',
#  'binnetice',
#  'binyıl',
#  'bip',
#  'biperva',
#  'bir',
#  'birader',
#  'birara',
#  'birarada',
#  'biraz',
#  'birazcık',
#  'birazdan',
#  'birbiri',
#  'birbirinde',
#  'birbirinden',
#  'birbirine',
#  'birbirini',
#  'birbirinin',
#  'birçoğu',
#  'birçoğuna',
#  'birçoğunda',
#  'birçoğundan',
#  'birçoğunu',
#  'birçoğunun',
#  'birçok',
#  'birçokları',
#  'birden',
#  'birdenbire',
#  'birer',
#  'birgün',
#  'biri',
#  'birice',
#  'birileri',
#  'birilerinde',
#  'birilerinden',
#  'birilerine',
#  'birilerini',
#  'birilerinin',
#  'birinci',
#  'birinde',
#  'birinden',
#  'birine',
#  'birini',
#  'birinin',
#  'birisi',
#  'birisinde',
#  'birisinden',
#  'birisine',
#  'birisini',
#  'birisinin',
#  'birkaç',
#  'birkaçı',
#  'birkaçına',
#  'birkaçında',
#  'birkaçından',
#  'birkaçını',
#  'birkaçının',
#  'birkez',
#  'birlikte',
#  'birşey',
#  'birşeyi',
#  'birtakım',
#  'bis',
#  'bismillâh',
#  'bitevi',
#  'biteviye',
#  'bittabi',
#  'biz',
#  'bizar',
#  'bizatihi',
#  'bizce',
#  'bizcileyin',
#  'bizden',
#  'bize',
#  'bizi',
#  'bizim',
#  'bizimki',
#  'bizzat',
#  'bodoslama',
#  'bodoslamadan',
#  'bolca',
#  'bönce',
#  'bonjur',
#  'boş',
#  'boşuna',
#  'boyca',
#  'boylamasına',
#  'boyle',
#  'böyle',
#  'böylece',
#  'böylecene',
#  'böylelikle',
#  'böylemesine',
#  'böylesi',
#  'böylesine',
#  'boyuna',
#  'boyunca',
#  'br',
#  'bravo',
#  'bre',
#  'bu',
#  'budalacasına',
#  'bugün',
#  'bugünden',
#  'bugünlük',
#  'bulanık',
#  'buna',
#  'bunca',
#  'bunda',
#  'bundan',
#  'bunlar',
#  'bunları',
#  'bunların',
#  'bunu',
#  'bunun',
#  'bünyece',
#  'buracıkta',
#  'burada',
#  'buradan',
#  'burası',
#  'burasına',
#  'burasında',
#  'burasından',
#  'burasını',
#  'burasının',
#  'büsbütün',
#  'bütün',
#  'bütünüyle',
#  'c',
#  'ç',
#  'caba',
#  'cabadan',
#  'çabucacık',
#  'çabucak',
#  'çabuk',
#  'çabukça',
#  'cahilane',
#  'çakırkeyif',
#  'çaktırmadan',
#  'çalak',
#  'çalakalem',
#  'çalakamçı',
#  'çalakaşık',
#  'çalakılıç',
#  'çalakürek',
#  'çalyaka',
#  'cana',
#  'candan',
#  'canıgönülden',
#  'caniyane',
#  'canıyürekten',
#  'canlı',
#  'cansiparane',
#  'çap',
#  'capcanlı',
#  'çapkın',
#  'çapraz',
#  'çaprazlama',
#  'çaprazlamasına',
#  'çaprazvari',
#  'çarçabuk',
#  'carcar',
#  'carcur',
#  'çarnaçar',
#  'çarpık',
#  'cartadak',
#  'cartadan',
#  'cebren',
#  'ceffelkalem',
#  'çekinik',
#  'ceman',
#  'çengüçağanak',
#  'çepçevre',
#  'çepeçevre',
#  'çeşitli',
#  'cesur',
#  'cesurane',
#  'cetbecet',
#  'cevaben',
#  'çeyrek',
#  'cicoz',
#  'cidden',
#  'ciddi',
#  'cihangirane',
#  'cihetiyle',
#  'cık',
#  'çıldırasıya',
#  'çılgıncasına',
#  'cılız',
#  'çinko',
#  'çınsabah',
#  'çırılçıplak',
#  'cıs',
#  'cismen',
#  'çocukça',
#  'çocuksu',
#  'çoğu',
#  'çoğun',
#  'çoğuna',
#  'çoğunca',
#  'çoğunda',
#  'çoğundan',
#  'çoğunlukla',
#  'çöğunlukla',
#  'çoğunu',
#  'çoğunun',
#  'çok',
#  'çokbilmiş',
#  'çokça',
#  'çökkün',
#  'çokları',
#  'çoklarınca',
#  'çokluk',
#  'çoklukla',
#  'çoktandır',
#  'cuk',
#  'cumbadak',
#  'cumburlop',
#  'cumhurca',
#  'cümle',
#  'cümlemizden',
#  'cümlemize',
#  'cümlemizi',
#  'cümlesi',
#  'cümlesinden',
#  'cümlesine',
#  'cümlesini',
#  'cümlesinin',
#  'cümleten',
#  'çünki',
#  'cünkü',
#  'çünkü',
#  'cuppadak',
#  'çüş',
#  'd',
#  'da',
#  'dadaş',
#  'dah',
#  'daha',
#  'dahası',
#  'dahi',
#  'dâhice',
#  'dahil',
#  'dâhil',
#  'dahilen',
#  'dâhilen',
#  'dâhiyane',
#  'daim',
#  'daima',
#  'dair',
#  'daki',
#  'dakika',
#  'dakikalarca',
#  'dakikasında',
#  'dalgın',
#  'dalgınlıkla',
#  'dalgündüz',
#  'dalkavukça',
#  'dalkılıç',
#  'dalöğle',
#  'dalya',
#  'damsız',
#  'dan',
#  'dandini',
#  'dangadak',
#  'dangalakça',
#  'dar',
#  'davetsiz',
#  'dayalı',
#  'dayanarak',
#  'dayı',
#  'de',
#  'dede',
#  'defa',
#  'defaatle',
#  'defalarca',
#  'defaten',
#  'değil',
#  'değin',
#  'deh',
#  'dehşet',
#  'dehşetli',
#  'dek',
#  'deki',
#  'dekreşendo',
#  'delice',
#  'delicesine',
#  'delikanlı',
#  'dembedem',
#  'deme',
#  'demek',
#  'demi',
#  'demin',
#  'demincek',
#  'deminden',
#  'denli',
#  'derakap',
#  'derece',
#  'derhal',
#  'derhâl',
#  'derinden',
#  'derinlemesine',
#  'derinliğine',
#  'derken',
#  'dervişane',
#  'destur',
#  'destursuz',
#  'desturun',
#  'devam',
#  'devre',
#  'devren',
#  'deyyus',
#  'diğer',
#  'diğeri',
#  'diğerinden',
#  'diğerine',
#  'diğerini',
#  'diğerleri',
#  'dikey',
#  'dikine',
#  'dikkat',
#  'dikkatli',
#  'diklemesine',
#  'dimdik',
#  'dimi',
#  'diminuendo',
#  'dinç',
#  'dince',
#  'dinen',
#  'direkt',
#  'dışarı',
#  'diye',
#  'doğaçlama',
#  'doğaçtan',
#  'doğallıkla',
#  'doğru',
#  'doğrudan',
#  'doğrusu',
#  'doğuştan',
#  'doksan',
#  'doksanar',
#  'doksanıncı',
#  'dokuz',
#  'dokuzar',
#  'dokuzuncu',
#  'dolayı',
#  'dolayısıyla',
#  'doludizgin',
#  'domuzuna',
#  'dörder',
#  'dördüncü',
#  'dört',
#  'dörtnala',
#  'dosdoğru',
#  'dostane',
#  'doyasıya',
#  'dün',
#  'dünden',
#  'dünyada',
#  'düpedüz',
#  'durmadan',
#  'dürzü',
#  'düt',
#  'duyguca',
#  'düzgün',
#  'e',
#  'ebediyen',
#  'edecek',
#  'eden',
#  'edepli',
#  'edepsizcesine',
#  'ederek',
#  'edibane',
#  'edilecek',
#  'ediliyor',
#  'edilmesi',
#  'ediyor',
#  'efece',
#  'efendi',
#  'efendim',
#  'efsus',
#  'eger',
#  'eğer',
#  'eğreti',
#  'eğri',
#  'eh',
#  'ekseri',
#  'ekseriya',
#  'ekseriyetle',
#  'ekstra',
#  'elaman',
#  'elan',
#  'elbet',
#  'elbette',
#  'elden',
#  'elektriksiz',
#  'elele',
#  'elhak',
#  'elhamdülillah',
#  'elhasıl',
#  'eliyle',
#  'elli',
#  'ellinci',
#  'ellişer',
#  'elveda',
#  'emaneten',
#  'emme',
#  'emprovize',
#  'en',
#  'enayicesine',
#  'ençok',
#  'ender',
#  'enikonu',
#  'enlemesine',
#  'epey',
#  'epeyce',
#  'epeydir',
#  'epeyi',
#  'epeyice',
#  'er',
#  'erden',
#  'ergeç',
#  'erken',
#  'erkence',
#  'erkenden',
#  'esasen',
#  'eşekçe',
#  'eskaza',
#  'eskiden',
#  'eşkin',
#  'esnasında',
#  'estağfurullah',
#  'etmesi',
#  'etraflı',
#  'etraflıca',
#  'etti',
#  'ettiği',
#  'ettiğini',
#  'evce',
#  'evcek',
#  'evelallah',
#  'evet',
#  'evleviyetle',
#  'evvel',
#  'evvela',
#  'evvelce',
#  'evvelden',
#  'evvelemirde',
#  'evveli',
#  'evvelleri',
#  'ey',
#  'eyvah',
#  'ezberden',
#  'ezbere',
#  'ezcümle',
#  'ezercesine',
#  'ezik',
#  'ezkaza',
#  'f',
#  'fakat',
#  'falan',
#  'falanca',
#  'faraza',
#  'farzımahal',
#  'farzımuhal',
#  'fasih',
#  'fatihane',
#  'fayrap',
#  'fazla',
#  'fazladan',
#  'fazlasıyla',
#  'felan',
#  'fena',
#  'fertik',
#  'fesuphanallah',
#  'fiilen',
#  'fikren',
#  'filan',
#  'filanca',
#  'filancanın',
#  'filhakika',
#  'filvaki',
#  'fır',
#  'fırdolayı',
#  'fıstıki',
#  'fıtraten',
#  'fonda',
#  'fondip',
#  'fora',
#  'forte',
#  'fortepiano',
#  'fortissimo',
#  'fücceten',
#  'g',
#  'ğ',
#  'gafilane',
#  'gah',
#  'gâh',
#  'gâhi',
#  'galiba',
#  'garanti',
#  'garip',
#  'gâvurcasına',
#  'gayet',
#  'gayetle',
#  'gayri',
#  'gayrı',
#  'geç',
#  'gece',
#  'geçe',
#  'geceleri',
#  'geceleyin',
#  'geçende',
#  'geçenlerde',
#  'gelgelelim',
#  'gelişigüzel',
#  'gene',
#  'genelde',
#  'genellikle',
#  'gepgenç',
#  'gerçekte',
#  'gerçekten',
#  'gerçi',
#  'gereği',
#  'gereğince',
#  'gerek',
#  'gerekse',
#  'geri',
#  'gerisingeri',
#  'gerisingeriye',
#  'gevşek',
#  'gibi',
#  'gibilerden',
#  'gibisinden',
#  'giderayak',
#  'giderek',
#  'gidi',
#  'gine',
#  'gırla',
#  'gitgide',
#  'gittikçe',
#  'gıyaben',
#  'gıyabında',
#  'gizli',
#  'gönlünce',
#  'gore',
#  'göre',
#  'görünürde',
#  'görünürlerde',
#  'görünüşte',
#  'götürü',
#  'güç',
#  'güçbela',
#  'güçlükle',
#  'gücün',
#  'gümbedek',
#  'günaşırı',
#  'günaydın',
#  'günbegün',
#  'günde',
#  'gündüz',
#  'gündüzleri',
#  'gündüzleyin',
#  'gündüzün',
#  'günlerce',
#  'günübirliğine',
#  'günübirlik',
#  'güpegündüz',
#  'gürpedek',
#  'güya',
#  'güzel',
#  'güzelim',
#  'güzellikle',
#  'güzün',
#  'h',
#  'ha',
#  'haa',
#  'habire',
#  'hacmen',
#  'haddizatında',
#  'hadi',
#  'hadisene',
#  'hafazanallah',
#  'hafif',
#  'hafiften',
#  'hafta',
#  'haftalarca',
#  'hah',
#  'hain',
#  'haincesine',
#  'hakeza',
#  'hakikat',
#  'hakikaten',
#  'hakimane',
#  'hâkimane',
#  'hakkında',
#  'hakkıyla',
#  'hala',
#  'hâlâ',
#  'halbuki',
#  'hâlbuki',
#  'halde',
#  'halen',
#  'hâlen',
#  'halihazırda',
#  'hâlihazırda',
#  'halisane',
#  'haliyle',
#  'hâliyle',
#  'hamdolsun',
#  'hamilen',
#  'handiyse',
#  'hangi',
#  'hangisi',
#  'hangisinde',
#  'hangisinden',
#  'hangisine',
#  'hani',
#  'hanımanne',
#  'hapur',
#  'harfiyen',
#  'hariç',
#  'haricen',
#  'harika',
#  'harrangürra',
#  'hart',
#  'hartadak',
#  'haşa',
#  'hâşâ',
#  'hasbelkader',
#  'hasebiyle',
#  'hasılı',
#  'haşin',
#  'hasmane',
#  'hassaten',
#  'hatta',
#  'havadan',
#  'hay',
#  'hayalen',
#  'haybeden',
#  'hayda',
#  'haydi',
#  'haydin',
#  'haydindi',
#  'haydisene',
#  'hayfa',
#  'hayhay',
#  'hayıf',
#  'hayır',
#  'hayli',
#  'hayret',
#  'hayretle',
#  'hayrola',
#  'haysiyetiyle',
#  'haza',
#  'hazır',
#  'hazret',
#  'he',
#  'helalinden',
#  'hele',
#  'hem',
#  'hemen',
#  'hemencecik',
#  'henüz',
#  'hep',
#  'hepsi',
#  'hepsinde',
#  'hepsinden',
#  'hepsine',
#  'hepsini',
#  'hepsinin',
#  'hepten',
#  'her',
#  'herbiri',
#  'her biri',
#  'herhâlde',
#  'herhangi',
#  'herkes',
#  'herkese',
#  'herkesi',
#  'herkesin',
#  'herkesten',
#  'herzaman',
#  'hey',
#  'heyetiyle',
#  'heyhat',
#  'hiç',
#  'hiçbir',
#  'hiçbiri',
#  'hiçbirinde',
#  'hiçbirinden',
#  'hiçbirine',
#  'hiçbirini',
#  'hiçbirinin',
#  'hiç kimse',
#  'hiçten',
#  'hilkaten',
#  'hımhım',
#  ...]

# %% [markdown]
# <span style="font-size:1.1em">Entrylerdeki harfler küçük harf haline getirilir</span>

# %%
df['entry'] = df['entry'].str.lower()
df['entry']
# Out:
# 0         ekşi itiraf sonunda döndüm dolaştım geldim ken...
# 1         selda bağcan bu sesi canlı dinleyebilmek benim...
# 2         eski sevgilisinin mutlu olmasını isteyen insan...
# 3         veda ederken 2019'a bir not bırakmak farklı ac...
# 4         ingiliz aksanı bu aralar özellikle bayıldığım ...
#                                 ...
# 524835            zlatan ibrahimoviç türkiye de katil olur
# 524836    tarihteki en büyük yalancılar şike operasyonu ...
# 524837              akp-chp koalisyonu hayali koalisyondur
# 524838    trabzonlu insana hamsi diyen fenerbahçe taraft...
# 524839    caner taslaman zonguldak taki paneline katılma...
# Name: entry, Length: 524840, dtype: object

# %% [markdown]
# <span style="font-size:1.1em;">Entrylerden noktalama işaretleri temizlenir.</span>

# %%
import string

df['entry'] = df['entry'].apply(lambda x: x.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation))))
df['entry']
# Out:
# 0         ekşi itiraf döndüm dolaştım geldim kendime çat...
# 1         selda bağcan sesi dinleyebilmek büyük mutluluk...
# 2         eski sevgilisinin mutlu olmasını isteyen insan...
# 3         veda ederken 2019 a not bırakmak farklı acılar...
# 4         ingiliz aksanı aralar bayıldığım konuşan insan...
#                                 ...
# 524835                     zlatan ibrahimoviç türkiye katil
# 524836    tarihteki büyük yalancılar şike operasyonu azi...
# 524837               akp chp koalisyonu hayali koalisyondur
# 524838    trabzonlu insana hamsi diyen fenerbahçe taraft...
# 524839    caner taslaman zonguldak paneline katılmaktan ...
# Name: entry, Length: 524840, dtype: object

# %% [markdown]
# <span style="font-size:1.1em">Entrylerden rakamlar silinir.</span>

# %%
df['entry'] = df['entry'].str.replace('\d+', ' ')
df['entry']
# Out:
# 0         ekşi itiraf döndüm dolaştım geldim kendime çat...
# 1         selda bağcan sesi dinleyebilmek büyük mutluluk...
# 2         eski sevgilisinin mutlu olmasını isteyen insan...
# 3         veda ederken   a not bırakmak farklı acılar mu...
# 4         ingiliz aksanı aralar bayıldığım konuşan insan...
#                                 ...
# 524835                     zlatan ibrahimoviç türkiye katil
# 524836    tarihteki büyük yalancılar şike operasyonu azi...
# 524837               akp chp koalisyonu hayali koalisyondur
# 524838    trabzonlu insana hamsi diyen fenerbahçe taraft...
# 524839    caner taslaman zonguldak paneline katılmaktan ...
# Name: entry, Length: 524840, dtype: object

# %% [markdown]
# <span style="font-size:1.1em;">Entrylerden web site linkleri silinir.</span>

# %%
df['entry'] = df['entry'].str.replace(r'http\S+', ' ', regex=True)
df['entry'] = df['entry'].str.replace(r'www\S+', '', regex=True)
df['entry']
# Out:
# 0         ekşi itiraf döndüm dolaştım geldim kendime çat...
# 1         selda bağcan sesi dinleyebilmek büyük mutluluk...
# 2         eski sevgilisinin mutlu olmasını isteyen insan...
# 3         veda ederken 2019'a not bırakmak farklı acılar...
# 4         ingiliz aksanı aralar bayıldığım konuşan insan...
#                                 ...
# 524835                     zlatan ibrahimoviç türkiye katil
# 524836    tarihteki büyük yalancılar şike operasyonu azi...
# 524837               akp-chp koalisyonu hayali koalisyondur
# 524838    trabzonlu insana hamsi diyen fenerbahçe taraft...
# 524839    caner taslaman zonguldak paneline katılmaktan ...
# Name: entry, Length: 524840, dtype: object

# %% [markdown]
# Entrylerden stop words'ler temizlenir.

# %%
df['entry'] = df['entry'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_word_list)]))
df['entry']
# Out:
# 0         ekşi itiraf döndüm dolaştım geldim kendime çat...
# 1         selda bağcan sesi dinleyebilmek büyük mutluluk...
# 2         eski sevgilisinin mutlu olmasını isteyen insan...
# 3         veda ederken 2019'a not bırakmak farklı acılar...
# 4         ingiliz aksanı aralar bayıldığım konuşan insan...
#                                 ...
# 524835                     zlatan ibrahimoviç türkiye katil
# 524836    tarihteki büyük yalancılar şike operasyonu azi...
# 524837               akp-chp koalisyonu hayali koalisyondur
# 524838    trabzonlu insana hamsi diyen fenerbahçe taraft...
# 524839    caner taslaman zonguldak paneline katılmaktan ...
# Name: entry, Length: 524840, dtype: object

# %% [markdown]
# Fazla olan whitespace karakterleri temizlenir.

# %%
df['entry'] = df['entry'].replace('\s+', ' ', regex=True)

# %% [markdown]
# <span style="font-size:1.1em">Verisetinin stemmera sokmadan önceki ön işlemeden geçirilmiş hali kaydedilir. Buradaki amaç stemmerdan geçirilmiş ve geçirilmemiş halinin başarı açısından karşılaştırılmasının yapılabilmesi.</span>

# %%
df.to_csv("gdrive/My Drive/mbti/preprocessed_dataset_no_stemming.csv", sep=';', encoding='utf-8', index=False)

# %% [markdown]
# <span style="font-size:1.1em">SnowballStemmer içerisinde Türkçe dili için kullanabileceğimiz TurkishStemmer import edilir. Stemmer ile kelimelerin köklerine ulaşılır. Lemmatization işlemiyle kök bulunduğu zaman elde edilen kökler biçimsel açıdan da doğru olurken (yani mantıksal açıdan da) stemmer ile elde edilen köklerde böyle bir durum söz konusu değildir. Dolayısıyla stemming edilmis hallerine bakıldıgında mantıksal açıdan düzgün sonuclar vermeyebilir.</span>

# %% [markdown]
# <span style="font-size:1.1em">Google Colab'a snowballstemmer ile ilgil package'i indirmek için aşağıdaki komutu çalıştırıyoruz.</span>

# %%
# !pip install snowballstemmer

# %%
from snowballstemmer import TurkishStemmer

# %%
stemmer = TurkishStemmer()
df['entry']

# %%
indexes = df.index

for i in range(len(indexes)):
    index = indexes[i]
    entry = df['entry'][index]
    entry_kokler = stemmer.stemWords(entry.split(" "))
    df['entry'][index] = " ".join(entry_kokler)

# %%
df['entry']

# %% [markdown]
# <span style="font-size:1.1em">Stemmera sokulmuş hali kaydedilir.</span>

# %%
df.to_csv("gdrive/My Drive/mbti/preprocessed_dataset_with_stemming.csv", sep=';', encoding='utf-8', index=False)
